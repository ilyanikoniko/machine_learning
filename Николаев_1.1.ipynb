# %% [markdown]
# # Упражнение 1. Синтаксис Markdown

# %% [markdown]
# # Заголовок первого уровня
# ## Заголовок второго уровня
# ### Заголовок третьего уровня
# #### Заголовок четвёртого уровня
# ##### Заголовок пятого уровня
# ###### Заголовок шестого уровня

# %% [markdown]
#  Блочная цитата

# %% [markdown]
# > Блочная цитата

# %% [markdown]
#  Блок кода (plain code block)

# %% [markdown]
# ```
# A plain code block
# ```

# %% [markdown]
# A plain code block

# %% [markdown]
#  Форматирование текста

# %% [markdown]
# **жирный текст**
# *курсив*
# `Monospaced text (e.g., code)`
# ~~вычеркнутый текст~~
# верхний индекс $s^2$

# %% [markdown]
#  Встроенное уравнение и блок уравнений

# %% [markdown]
# Встроенное уравнение: $E = mc^2$
#
# Блок уравнений:
# $$E = mc^2$$

# %% [markdown]
#  Гиперссылка

# %% [markdown]
# [Гиперссылка (на rmarkdown.rstudio.com)](http://rmarkdown.rstudio.com)

# %% [markdown]
#  Горизонтальная линейка

# %% [markdown]
# ---

# %% [markdown]
#  Ненумерованный список с подпунктами

# %% [markdown]
# - Пункт 1
# - Пункт 2
#   - подпункт 1
#   - подпункт 2

# %% [markdown]
#  Упорядоченный список с подпунктами

# %% [markdown]
# <ol>
#   <li>Пункт 1</li>
#   <li>Пункт 2
#     <ol type="a">
#       <li>подпункт 1</li>
#       <li>подпункт 2</li>
#     </ol>
#   </li>
# </ol>

# %% [markdown]
#  Таблица

# %% [markdown]
# | Заголовок 1 | Заголовок 2 |
# |-------------|-------------|
# | Ячейка 1    | Ячейка 2    |
# | Ячейка 3    | Ячейка 4    |
